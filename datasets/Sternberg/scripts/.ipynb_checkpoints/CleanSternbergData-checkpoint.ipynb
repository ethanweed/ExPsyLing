# %%
# Define a function to simplify and clean Sternberg data

def wrangleSternberg(raw):


    # create a new dataframe with only the data we need from raw
    df = pd.DataFrame({'id': raw['id'],
                       'block': raw['block'],
                       'correct': raw['correct'],
                       'setSize': raw['setSize'],
                       'present': raw['present'],
                       'rt': raw['response_time']})

    # find all the unique session id's from the raw data
    #ids = list(set(df['sessionid']))

    # make a new column with a simple ID number for each participant
    #id = []
    #for s, val in enumerate(df['sessionid']):
    #    for i, num in enumerate(ids):
    #        if val == num:
    #            id.append(i+1)            
    #df['id'] = id


    #ids = list(set(df['id']))
    

    # remove practice trials
    df = df.loc[df['block'] != "practice"]

    # keep only correct answers
    df = df.loc[df['correct'] == 1]

    # keep only the data we need
    keep = ['id', 'setSize', 'present','rt']
    df = df[keep]

    #group_by(setSize, present, id) 
    data = df.groupby(['setSize', 'present', 'id']).agg('mean')

    # de-sparsify the dataframe index
    data = data.reset_index()
    
    # print the number of participants we have data for
    print("Data for", len(list(set(df['id']))), "participants cleaned!")

    return(data)

# %%
# Load the raw Sternberg data

import pandas as pd

file = "/Users/ethan/Documents/GitHub/ExPsyLing/datasets/Sternberg/2021/Sternberg_all.csv"

raw = pd.read_csv(file)

# %%
# Clean the data
raw
#data = wrangleSternberg(raw)
# Out:
#       Unnamed: 0    acc  accuracy  average_response_time  avg_rt background  \
# 0              0  100.0     100.0                  547.0   547.0      black
# 1              1   50.0      50.0                  400.0   400.0      black
# 2              2   67.0      67.0                  455.0   455.0      black
# 3              3   75.0      75.0                  454.0   454.0      black
# 4              4   80.0      80.0                  521.0   521.0      black
# ...          ...    ...       ...                    ...     ...        ...
# 6043         133   94.0      94.0                  963.0   963.0      black
# 6044         134   94.0      94.0                  963.0   963.0      black
# 6045         135   94.0      94.0                  961.0   961.0      black
# 6046         136   94.0      94.0                  960.0   960.0      black
# 6047         137   94.0      94.0                  959.0   959.0      black
#
#      bidi       block browser_codename browser_name  ...              title  \
# 0      no    practice          Mozilla     Netscape  ...  Sternberg_updated
# 1      no    practice          Mozilla     Netscape  ...  Sternberg_updated
# 2      no    practice          Mozilla     Netscape  ...  Sternberg_updated
# 3      no    practice          Mozilla     Netscape  ...  Sternberg_updated
# 4      no    practice          Mozilla     Netscape  ...  Sternberg_updated
# ...   ...         ...              ...          ...  ...                ...
# 6043   no  experiment          Mozilla     Netscape  ...  Sternberg_updated
# 6044   no  experiment          Mozilla     Netscape  ...  Sternberg_updated
# 6045   no  experiment          Mozilla     Netscape  ...  Sternberg_updated
# 6046   no  experiment          Mozilla     Netscape  ...  Sternberg_updated
# 6047   no  experiment          Mozilla     Netscape  ...  Sternberg_updated
#
#      total_correct total_response_time total_responses  uniform_coordinates  \
# 0              1.0               547.0             1.0                  yes
# 1              1.0               800.0             2.0                  yes
# 2              2.0              1366.0             3.0                  yes
# 3              3.0              1815.0             4.0                  yes
# 4              4.0              2604.0             5.0                  yes
# ...            ...                 ...             ...                  ...
# 6043         126.0            129040.0           134.0                  yes
# 6044         127.0            130011.0           135.0                  yes
# 6045         128.0            130677.0           136.0                  yes
# 6046         129.0            131525.0           137.0                  yes
# 6047         130.0            132301.0           138.0                  yes
#
#        width  id  rt Unnamed: 0.1  participant_id
# 0     1024.0   1 NaN          NaN             NaN
# 1     1024.0   1 NaN          NaN             NaN
# 2     1024.0   1 NaN          NaN             NaN
# 3     1024.0   1 NaN          NaN             NaN
# 4     1024.0   1 NaN          NaN             NaN
# ...      ...  ..  ..          ...             ...
# 6043  1024.0  23 NaN          NaN             NaN
# 6044  1024.0  23 NaN          NaN             NaN
# 6045  1024.0  23 NaN          NaN             NaN
# 6046  1024.0  23 NaN          NaN             NaN
# 6047  1024.0  23 NaN          NaN             NaN
#
# [6048 rows x 133 columns]

# %%
# Save the cleaned data

data.to_csv("/Users/ethan/Documents/GitHub/ExPsyLing/datasets/Sternberg/2021/Sternberg_cleaned.csv",
           index = False)
