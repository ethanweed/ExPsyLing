# %%
import pandas as pd

# %%
raw = pd.read_csv('/work/E2026/ExPsyLing/experiments/masked_prime/data/combined_data.csv')

# %%
#raw.head(50)

# %%
list(raw)
# Out:
# ['participant_id',
#  'component_num',
#  'url',
#  'meta',
#  'sender',
#  'sender_type',
#  'sender_id',
#  'ended_on',
#  'duration',
#  'time_run',
#  'time_render',
#  'time_show',
#  'time_end',
#  'time_commit',
#  'timestamp',
#  'time_switch',
#  'response',
#  'response_action',
#  'prime',
#  'target',
#  'condition',
#  'soa_condition',
#  'congruence',
#  'correct_response',
#  'correctResponse',
#  'correct']

# %%
cols = ['participant_id', 'sender', 'duration', 'response', 'condition','soa_condition',
        'congruence', 'correct_response', 'correct']

# %%
df = raw[cols]

# %%
df = df[df['sender'] == 'target']

# %%
df
# Out:
#        participant_id  sender  duration response        condition  \
# 13                 51  target    843.38        n         practice
# 19                 51  target    593.04        m         practice
# 25                 51  target    559.18        m         practice
# 31                 51  target    653.76        n         practice
# 40                 51  target    520.14        m  Inc_Synth_Synth
# ...               ...     ...       ...      ...              ...
# 15606              69  target    699.20        m        Con_Synth
# 15612              69  target    580.20        n          Con_Nat
# 15618              69  target    577.90        m    Inc_Nat_Synth
# 15624              69  target    661.10        n    Inc_Synth_Nat
# 15630              69  target    709.20        n      Inc_Nat_Nat
#
#       soa_condition   congruence correct_response correct
# 13         practice     practice                n    True
# ...

# %%
df['sender'].unique()
# Out:
# <StringArray>
# ['target']
# Length: 1, dtype: str
