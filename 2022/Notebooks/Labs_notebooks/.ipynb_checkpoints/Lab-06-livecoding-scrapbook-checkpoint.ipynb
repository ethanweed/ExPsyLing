# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

url = 'https://osf.io/download/r7udh/'

df = pd.read_csv(url)

# %%
df.head(10)
# Out:
#     Participant.ID Version Set  Subset      Baseword Diversity  Item  \
# 0                1      B2   B       2         shirt       low  hust
# 7                1      B2   B       1     cockroach      high  veak
# 14               1      B2   B       2          sled       low  deam
# 21               1      B2   B       1        tissue      high  bamp
# 28               1      B2   B       2           car       low  zove
# 35               1      B2   B       1     cigarette      high  coft
# 42               1      B2   B       2       frisbee       low  yark
# 49               1      B2   B       1           dog      high  hoad
# 56               2      A1   A       1        carrot       low  flam
# 63               2      A1   A       1  window blind       low  tock
#
#                                              Question  Response.Box  \
# 0   Earlier you read about a type of shirt that wa...             1
# 7   Earlier you read about a type of cockroach tha...             1
# 14  Earlier you read about a type of sled that was...             1
# 21  Earlier you read about a type of tissue that w...             1
# 28  Earlier you read about a type of car that was ...             1
# 35  Earlier you read about a type of cigarette tha...             1
# 42  Earlier you read about a type of frisbee that ...             1
# 49  Earlier you read about a type of dog that was ...             1
# 56  Earlier you read about a type of carrot that w...             1
# 63  Earlier you read about a type of window blind ...             1
#
#                                              Response  Score
# 0                                            stretchy    3.0
# 7                               native to New Zealand    2.0
# 14                  can fit one adult or two children    2.0
# 21                               made of panda faeces    4.0
# 28  you can remove the steering wheel to enable au...    4.0
# 35                                   it is extra long    3.0
# 42                             it comes in 30 colours    3.0
# 49                        they have bright green eyes    3.0
# 56                                      purple colour    3.0
# 63                              expensive to install     5.0

# %%
print(len(set(df['Participant.ID'])))
print(len(df.loc[df['Diversity'] == 'low']))
print(len(df.loc[df['Diversity'] == 'high']))
# Out:
# 100
# 400
# 400

# %%
sns.histplot(df.loc[df['Diversity'] == 'low'], x = 'Score')
# Out:
# <AxesSubplot:xlabel='Score', ylabel='Count'>

# %%
df.loc[df['Diversity'] == 'low']['Score'].unique()
# Out:
# array([3., 2., 4., 5., 1., 0.])

# %%
df = df.dropna()
df['Score'].astype(int)

fig, axes = plt.subplots(1, 2, figsize=(15, 5))

df_low = df.loc[df['Diversity'] == 'low']
df_high = df.loc[df['Diversity'] == 'high']


sns.histplot(df_low, x = 'Score', bins = 6, ax = axes[0])
sns.histplot(df_high, x = 'Score', bins = 6, ax = axes[1])
# Out:
# <AxesSubplot:xlabel='Score', ylabel='Count'>

# %%
sns.kdeplot(data = df, x = 'Score', hue = 'Diversity')
# Out:
# <AxesSubplot:xlabel='Score', ylabel='Density'>

# %%
sns.catplot(data = df, x = 'Diversity', y = 'Score', kind = 'violin')

# %%
sns.catplot(data = df, x = 'Diversity', y = 'Score', kind = 'point')

# %%
print(df_low['Score'].mean())
print(df_high['Score'].mean())
# Out:
# 2.76
# 2.3925

# %%
import numpy as np

sim_low = []
for i in range(10):
    sim_low.append(np.random.choice(df_low['Score'], 50, replace = True))

sim_high = []
for i in range(10):
    sim_high.append(np.random.choice(df_high['Score'], 50, replace = True))

# %%
#sim_low[0:2]
# Out:
# [array([3., 4., 4., 1., 1., 4., 1., 2., 2., 4., 2., 2., 4., 5., 1., 1., 2.,
#         4., 3., 3., 1., 2., 4., 5., 3., 2., 1., 3., 1., 3., 3., 1., 2., 3.,
#         4., 4., 5., 2., 3., 2., 0., 4., 4., 4., 2., 5., 3., 1., 5., 2.]),
#  array([4., 4., 5., 2., 1., 3., 4., 5., 4., 3., 2., 3., 4., 3., 3., 0., 2.,
#         4., 4., 4., 3., 3., 5., 4., 3., 2., 3., 1., 4., 0., 2., 4., 1., 2.,
#         4., 0., 4., 0., 2., 2., 4., 3., 1., 4., 4., 2., 3., 4., 1., 4.])]

# %%
import numpy as np

sim_low = []
for i in range(10):
    sim_low.append(np.random.choice(df_low['Score'], 50, replace = True))

sim_high = []
for i in range(10):
    sim_high.append(np.random.choice(df_high['Score'], 50, replace = True))

sim_data_low = pd.DataFrame(sim_low)
sim_means_low = sim_data_low.mean()

sim_data_high = pd.DataFrame(sim_high)
sim_means_high = sim_data_high.mean()

sim_data_low = sim_data_low.melt(var_name = 'id', value_name = 'score')
sim_data_high = sim_data_high.melt(var_name = 'id', value_name = 'score')

sim_data_low['Diversity'] = ['low']*len(sim_data_low)
sim_data_high['Diversity'] = ['high']*len(sim_data_high)

sim_data_long = pd.concat([sim_data_low,sim_data_high])

sns.pointplot(data = sim_data_long, x = 'id', y = 'score', hue = 'Diversity', linestyle = ' ')
# Out:
# <AxesSubplot:xlabel='id', ylabel='score'>

# %%
sim_low = []
for i in range(10):
    sim_low.append(np.random.choice(df_low['Score'], 50, replace = True))

sim_high = []
for i in range(10):
    sim_high.append(np.random.choice(df_high['Score'], 50, replace = True))

sim_data_low = pd.DataFrame(sim_low)
sim_means_low = sim_data_low.mean()

sim_data_high = pd.DataFrame(sim_high)
sim_means_high = sim_data_high.mean()

sim_data_low = sim_data_low.melt(var_name = 'id', value_name = 'score')
sim_data_high = sim_data_high.melt(var_name = 'id', value_name = 'score')

sim_data_low['Diversity'] = ['low']*len(sim_data_low)
sim_data_high['Diversity'] = ['high']*len(sim_data_high)

sim_data_long = pd.concat([sim_data_low,sim_data_high])

#sns.pointplot(data = sim_data_long, x = 'id', y = 'score', hue = 'Diversity', linestyle = ' ')

sim_data_long = sim_data_long.groupby(['id', 'Diversity']).mean()
sim_data_long.reset_index(inplace = True)
sim_data_long
# Out:
#     id Diversity  score
# 0    0      high    2.2
# 1    0       low    2.9
# 2    1      high    1.8
# 3    1       low    1.9
# 4    2      high    2.2
# ..  ..       ...    ...
# 95  47       low    2.4
# 96  48      high    1.5
# 97  48       low    2.6
# 98  49      high    2.8
# 99  49       low    2.5
#
# [100 rows x 3 columns]

# %%
sns.pointplot(data = sim_data_long, 
              x = 'id', 
              y = 'score', 
              hue = 'Diversity')
sns.despine()

# %%
compare = zip(sim_data_long.loc[sim_data_long['Diversity'] == 'high']['score'],
              sim_data_long.loc[sim_data_long['Diversity'] == 'low']['score'])
compare = list(compare)
compare
# Out:
# [(2.2, 2.9),
#  (1.8, 1.9),
#  (2.2, 3.0),
#  (2.7, 2.1),
#  (1.8, 3.3),
#  (2.6, 3.4),
#  (2.2, 2.6),
#  (2.8, 2.5),
#  (2.2, 2.7),
#  (2.4, 2.7),
#  (2.3, 2.5),
#  (2.3, 2.2),
#  (1.5, 3.0),
#  (2.2, 2.4),
#  (2.6, 2.9),
#  (3.0, 2.0),
#  (2.6, 2.0),
#  (1.9, 2.7),
#  (2.3, 3.5),
#  (2.4, 3.1),
#  (2.1, 3.4),
#  (2.6, 2.7),
#  (2.3, 2.1),
#  (1.5, 2.3),
#  (2.8, 2.9),
#  (2.7, 2.7),
#  (3.5, 3.2),
#  (1.9, 1.8),
#  (2.4, 3.4),
#  (3.1, 3.1),
#  (2.6, 2.3),
#  (1.6, 2.8),
#  (2.5, 2.7),
#  (2.9, 2.9),
#  (2.0, 3.0),
#  (3.0, 3.0),
#  (2.2, 3.0),
#  (2.4, 2.6),
#  (2.3, 2.6),
#  (2.6, 3.1),
#  (2.6, 2.7),
#  (2.1, 2.7),
#  (2.8, 2.5),
#  (2.3, 3.0),
#  (2.4, 2.6),
#  (2.0, 2.7),
#  (2.2, 3.2),
#  (2.3, 2.4),
#  (1.5, 2.6),
#  (2.8, 2.5)]

# %%
highs = [1 for x in compare if x[0]>x[1]]
lows = [1 for x in compare if x[0]<x[1]]
same = [1 for x in compare if x[0]==x[1]]
print(sum(highs))
print(sum(lows))
print(sum(same))
# Out:
# 11
# 35
# 4

# %%
print(df_sim_means['Low'].mean())
print(df_sim_means['High'].mean())
# Out:
# 2.6879999999999997
# 2.375

# %%
means_low = []
for i in range(5):
    means_low.append(np.random.choice(df_low['Score'], 10, replace = True))

means_high = []
for i in range(5):
    means_high.append(np.random.choice(df_high['Score'], 10, replace = True))
    
sim_data_low = pd.DataFrame(means_low)
sim_means_low = sim_data_low.mean()

sim_data_high = pd.DataFrame(means_high)
sim_means_high = sim_data_high.mean()

sns.catplot(data = df_sim_means, kind = 'violin')

# %%
df_sim_means_long = df_sim_means.melt(var_name = 'Diversity', value_name = 'Score')

# %%
df_sim_means_long.head()
# Out:
#   Diversity  Score
# 0       Low   2.57
# 1       Low   2.80
# 2       Low   2.95
# 3       Low   2.65
# 4       Low   2.55

# %%
list(df_sim_means_long)
# Out:
# ['Diversity', 'Score']
