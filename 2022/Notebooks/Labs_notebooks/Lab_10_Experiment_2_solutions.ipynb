# %% [markdown]
# # Lab Report 2
#
# **Research question 1**: Can we observe a masked priming effect (in a non-native language)?
#
# **Research question 2**: If there is a masked priming effect, does it increase, decrease, or stay the same after a short period of time (80 ms)?
#
# **Research question 3**: If there is a masked priming effect, is there also a semantic priming effect (in the incongruent pairs)?
#
# Other things to check:
#
# - did participants improve over time (both within blocks and over all trials)?
# - did it make a difference whether participants were in block A or block B (short SOA then long vs. long SOA then short)?
# - ???
#
# Two main communications: short and long Stimulus Onset Asynchrony (SOA)
#
# - Fixation: ###### 539 ms
# - Mask: ##### 32 ms
# - Prime: 32 ms
# - Mask: ##### 32 ms
# - (short SOA condition): 0 ms break. Proceed directly to target
# - (long condition): Blank screen: 80 ms
# - Target: timeout after 2000 ms
#
# 30 prime/target pairs in the short condition and 30 pairs in the long condition
#
# Approx. half the participants saw the short SOA first (group A), and half saw the long SOA first (group B).
#
# Congruent and Incongruent stimuli were fully randomised within each SOA block
#
# Stimuli were taken from:
#
# Peel, H. J., Royals, K. A., & Chouinard, P. A. (2022). The effects of word identity, case, and SOA on word priming in a subliminal context. _Journal of Psycholinguistic Research, 51_(1), 1-15.

# %%
# Setup

import numpy as np
import pandas as pd
import pingouin as pg
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Combine the group A and group B data

# %%
rawA = 'https://raw.githubusercontent.com/ethanweed/ExPsyLing/master/datasets/Masked_repetition_priming/MR_A.csv' 
rawB = 'https://raw.githubusercontent.com/ethanweed/ExPsyLing/master/datasets/Masked_repetition_priming/MR_B.csv'

raw_a = pd.read_csv(rawA)
raw_b = pd.read_csv(rawB)

df_A = pd.DataFrame({"id": raw_a['jatosStudyResultId'],
                     "counter_balance": raw_a['counterbalance'],
                     "condition": raw_a['condition'],
                     "rt": raw_a['response_time'],
                     "congruence": raw_a['congruence'],
                     "soa": raw_a['soa_condition'],
                     "correct": raw_a['correct']})
df_A = df_A.loc[df_A['soa'] != 'practice']
df_A.head()


df_B = pd.DataFrame({"id": raw_b['jatosStudyResultId'],
                     "counter_balance": raw_b['counterbalance'],
                     "condition": raw_b['condition'],
                     "rt": raw_b['response_time'],
                     "congruence": raw_b['congruence'],
                     "soa": raw_b['soa_condition'],
                     "correct": raw_b['correct']})
df_B = df_B.loc[df_B['soa'] != 'practice']
df_B.head()

df = pd.concat([df_A,df_B])

# %% [markdown]
# Make a quick plot

# %%
sns.pointplot(data = df, x = 'soa', y = 'rt', hue = 'congruence')
# Out:
# <AxesSubplot:xlabel='soa', ylabel='rt'>

# %% [markdown]
# Let's take a look at the individual trials.

# %%
sns.scatterplot(data = df, x = 'soa', y = 'rt', hue = 'congruence')
# Out:
# <AxesSubplot:xlabel='soa', ylabel='rt'>

# %% [markdown]
# Too many datapoints on top of each other. Can't see anything! Make a different plot:

# %%
sns.boxplot(data = df, x = 'soa', y = 'rt', hue = 'congruence')
sns.despine()

# %% [markdown]
# Hmm. There are some outliers. Let's try without them..

# %%
sns.boxplot(data = df.loc[df['rt'] < 1200], x = 'soa', y = 'rt', hue = 'congruence')
# Out:
# <AxesSubplot:xlabel='soa', ylabel='rt'>

# %%
sns.pointplot(data = df.loc[df['rt'] < 1200], x = 'soa', y = 'rt', hue = 'congruence')
# Out:
# <AxesSubplot:xlabel='soa', ylabel='rt'>

# %% [markdown]
# How many rows of data did we throw away, when we got rid of the "outliers"?

# %%
df.shape[0] - df.loc[df['rt'] < 1200].shape[0]
# Out:
# 392

# %% [markdown]
# Did all the outliers come from the same person, or lots of different people?

# %%
outliers = df[df['rt'] > 1200]
outliers['id'].unique()
# Out:
# array([799, 796, 795, 794, 789, 788, 784, 777, 772, 770, 769, 802, 800,
#        798, 797, 792, 791, 786, 783, 779, 776, 773])

# %% [markdown]
# It looks like it was lots of different people. Did _all_ the participants have some scores above 1200 ms? Let's compare the array of ID's of the participants in the full data set with the ID's of the participants who had some RT's longer than 1200 ms, to see if they are exactly the same:

# %%
np.array_equal(outliers['id'].unique(), df['id'].unique())
# Out:
# False

# %% [markdown]
# Ok, so there were some participants who never took over 1200 ms. Who were they, and how many of them were there?

# %%
speed_demons = [x for x in df['id'].unique() if x not in outliers['id'].unique()]
speed_demons
# Out:
# [785]

# %% [markdown]
# Ok, so there was actually only one participant who didn't have at least one "outlier" datapoint. Is there anything else unusual about this person's data? Let's plot participant 785's data together with everybody else's data (with outliers removed).

# %%
sns.pointplot(data = df.loc[((df['rt'] < 1200) & (df['id'] != 785))], 
              x = 'soa', y = 'rt', 
              hue = 'congruence')
sns.pointplot(data = df.loc[df['id'] == 785], x = 'soa', y = 'rt', hue = 'congruence')
# Out:
# <AxesSubplot:xlabel='soa', ylabel='rt'>

# %% [markdown]
# No, not really. The overall pattern is the same, they are just substantially faster than everybody else. What about their accuracy? Were they fast, but sloppy?

# %%
def accuracy(data):
    correct = len(data[data['correct']== 1])
    errors = len(data[data['correct']== 0])
    percent_correct = round((correct / (correct + errors)) * 100, 2)
    return(percent_correct)

# %%
accuracy(df.loc[df['id'] == 785])
# Out:
# 74.17

# %%
accuracy(df.loc[df['id'] != 785])
# Out:
# 68.22

# %% [markdown]
# No, not only was this person faster than everybody else, they also made fewer mistakes. Now, what happens if we look at the data after removing the trials on which people made mistakes...?

# %%
sns.pointplot(data = df.loc[((df['rt'] < 1200) & (df['correct'] == 1))], 
              x = 'soa', y = 'rt', 
              hue = 'congruence')
# Out:
# <AxesSubplot:xlabel='soa', ylabel='rt'>

# %% [markdown]
# Could there be any semantic priming effect in the incongruent data? That is, do "natural" primes prime "natural" targets, even when they are incongruent?

# %%
sns.pointplot(data = df.loc[((df['rt'] < 1200) & 
                             (df['correct'] == 1) & 
                             (df['congruence'] == 'incongruent'))], 
              y = 'condition', 
              x = 'rt')
# Out:
# <AxesSubplot:xlabel='rt', ylabel='condition'>

# %% [markdown]
# Huh. That looks weird. What's going on with that Nat_Nat_Synth?

# %%
natnatsynth = df[df['condition'] == 'Nat_Nat_Synth']
natnatsynth
# Out:
#        id counter_balance      condition    rt   congruence    soa  correct
# 53    799               A  Nat_Nat_Synth  1030  incongruent  short        0
# 176   796               A  Nat_Nat_Synth  1080  incongruent  short        0
# 301   795               A  Nat_Nat_Synth  1226  incongruent  short        0
# 408   794               A  Nat_Nat_Synth  1964  incongruent  short        1
# 520   789               A  Nat_Nat_Synth   782  incongruent  short        0
# 639   788               A  Nat_Nat_Synth   901  incongruent  short        0
# 764   785               A  Nat_Nat_Synth   590  incongruent  short        0
# 876   784               A  Nat_Nat_Synth   862  incongruent  short        0
# 1010  777               A  Nat_Nat_Synth   786  incongruent  short        0
# 1140  772               A  Nat_Nat_Synth   756  incongruent  short        0
# 1272  770               A  Nat_Nat_Synth   862  incongruent  short        0
# 1368  769               A  Nat_Nat_Synth  1942  incongruent  short        0
# 70    802               B  Nat_Nat_Synth   861  incongruent  short        0
# 201   800               B  Nat_Nat_Synth   745  incongruent  short        0
# 313   798               B  Nat_Nat_Synth   722  incongruent  short        0
# 478   797               B  Nat_Nat_Synth  1128  incongruent  short        0
# 577   792               B  Nat_Nat_Synth   826  incongruent  short        0
# 743   791               B  Nat_Nat_Synth  1188  incongruent  short        1
# 859   786               B  Nat_Nat_Synth   869  incongruent  short        0
# 936   783               B  Nat_Nat_Synth  1003  incongruent  short        0
# 1075  779               B  Nat_Nat_Synth   913  incongruent  short        0
# 1202  776               B  Nat_Nat_Synth  1173  incongruent  short        0
# 1358  773               B  Nat_Nat_Synth  1025  incongruent  short        0

# %%
natnatsynth = raw_a[raw_a['condition'] == 'Nat_Nat_Synth']
nns = pd.DataFrame(natnatsynth, columns = ['prime', 'target'])
nns
# Out:
#       prime target
# 53    finch  SLOTH
# 176   finch  SLOTH
# 301   finch  SLOTH
# 408   finch  SLOTH
# 520   finch  SLOTH
# 639   finch  SLOTH
# 764   finch  SLOTH
# 876   finch  SLOTH
# 1010  finch  SLOTH
# 1140  finch  SLOTH
# 1272  finch  SLOTH
# 1368  finch  SLOTH

# %%
natnatsynth = raw_b[raw_b['condition'] == 'Nat_Nat_Synth']
nns = pd.DataFrame(natnatsynth, columns = ['prime', 'target'])
nns
# Out:
#       prime target
# 70    finch  SLOTH
# 201   finch  SLOTH
# 313   finch  SLOTH
# 478   finch  SLOTH
# 577   finch  SLOTH
# 743   finch  SLOTH
# 859   finch  SLOTH
# 936   finch  SLOTH
# 1075  finch  SLOTH
# 1202  finch  SLOTH
# 1358  finch  SLOTH

# %% [markdown]
# Ah. It seems like there is one item I mislabled, the one where "finch" primes "SLOTH". That should be easy to fix...

# %% [markdown]
# From here on, it's up to you. Clean up my mess with finch/SLOTH, and do some appropriate analyses to get answers to the research questions...

# %% [markdown]
# ## Main analysis: 2-2 ANOVA

# %%
aov = pg.rm_anova(data = df, 
               dv = 'rt', 
               within = ['congruence', 'soa'],
               subject = 'id')
aov
# Out:
#              Source            SS  ddof1  ddof2            MS          F  \
# 0        congruence  27378.050048      1     22  27378.050048  15.337799
# 1               soa  20738.017440      1     22  20738.017440   5.084641
# 2  congruence * soa  26361.816425      1     22  26361.816425  12.020311
#
#       p-unc  p-GG-corr       ng2  eps
# 0  0.000739   0.000739  0.014364  1.0
# 1  0.034427   0.034427  0.010918  1.0
# 2  0.002191   0.002191  0.013838  1.0

# %%
sns.pointplot(data = df.loc[((df['rt'] < 1200) & (df['correct'] == 1))], 
              x = 'soa', y = 'rt', 
              hue = 'congruence')
# Out:
# <AxesSubplot:xlabel='soa', ylabel='rt'>

# %%
pg.pairwise_ttests(data = df, dv = 'rt', within = ['soa', 'congruence'], subject = 'id', padjust='bonf')
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In [85], line 1
# ----> 1 pg.pairwise_ttests(data = df, dv = 'rt', subject = 'id', padjust='bonf')
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pingouin/pairwise.py:28, in pairwise_ttests(*args, **kwargs)
#      26 """This function has been deprecated . Use :py:func:`pingouin.pairwise_tests` instead."""
#      27 warnings.warn("pairwise_ttests is deprecated, use pairwise_tests instead.", UserWarning)
# ---> 28 return pairwise_tests(*args, **kwargs)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pingouin/pairwise.py:480, in pairwise_tests(data, dv, between, within, subject, parametric, marginal, alpha, alternative, padjust, effsize, correction, nan_policy, return_desc, interaction, within_first)
#     478     else:
#     479         tmp = data
# --> 480     pt = pairwise_tests(
#     481         dv=dv,
#     482         between=fbt[i],
#     483         within=fwt[i],
#     484         subject=subject,
#     485         data=tmp,
#     486         parametric=parametric,
#     487         marginal=marginal,
#     488         alpha=alpha,
#     489         alternative=alternative,
#     490         padjust=padjust,
#     491         effsize=effsize,
#     492         correction=correction,
#     493         nan_policy=nan_policy,
#     494         return_desc=return_desc,
#     495     )
#     496     stats = pd.concat([stats, pt], axis=0, ignore_index=True, sort=False)
#     498 # Then compute the interaction between the factors
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pingouin/pairwise.py:480, in pairwise_tests(data, dv, between, within, subject, parametric, marginal, alpha, alternative, padjust, effsize, correction, nan_policy, return_desc, interaction, within_first)
#     478     else:
#     479         tmp = data
# --> 480     pt = pairwise_tests(
#     481         dv=dv,
#     482         between=fbt[i],
#     483         within=fwt[i],
#     484         subject=subject,
#     485         data=tmp,
#     486         parametric=parametric,
#     487         marginal=marginal,
#     488         alpha=alpha,
#     489         alternative=alternative,
#     490         padjust=padjust,
#     491         effsize=effsize,
#     492         correction=correction,
#     493         nan_policy=nan_policy,
#     494         return_desc=return_desc,
#     495     )
#     496     stats = pd.concat([stats, pt], axis=0, ignore_index=True, sort=False)
#     498 # Then compute the interaction between the factors
#
#     [... skipping similar frames: pairwise_tests at line 480 (2939 times)]
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pingouin/pairwise.py:480, in pairwise_tests(data, dv, between, within, subject, parametric, marginal, alpha, alternative, padjust, effsize, correction, nan_policy, return_desc, interaction, within_first)
#     478     else:
#     479         tmp = data
# --> 480     pt = pairwise_tests(
#     481         dv=dv,
#     482         between=fbt[i],
#     483         within=fwt[i],
#     484         subject=subject,
#     485         data=tmp,
#     486         parametric=parametric,
#     487         marginal=marginal,
#     488         alpha=alpha,
#     489         alternative=alternative,
#     490         padjust=padjust,
#     491         effsize=effsize,
#     492         correction=correction,
#     493         nan_policy=nan_policy,
#     494         return_desc=return_desc,
#     495     )
#     496     stats = pd.concat([stats, pt], axis=0, ignore_index=True, sort=False)
#     498 # Then compute the interaction between the factors
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pingouin/pairwise.py:470, in pairwise_tests(data, dv, between, within, subject, parametric, marginal, alpha, alternative, padjust, effsize, correction, nan_policy, return_desc, interaction, within_first)
#     467         paired = True
#     468         agg = [True, False]
# --> 470 stats = pd.DataFrame()
#     471 for i, f in enumerate(factors):
#     472     # Introduced in Pingouin v0.3.2
#     473     # Note that is only has an impact in the between test of mixed
#     474     # designs. Indeed, a similar groupby is applied by default on
#     475     # each within-subject factor of a two-way repeated measures design.
#     476     if all([agg[i], marginal]):
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:662, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     656     mgr = self._init_mgr(
#     657         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     658     )
#     660 elif isinstance(data, dict):
#     661     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 662     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     663 elif isinstance(data, ma.MaskedArray):
#     664     import numpy.ma.mrecords as mrecords
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py:493, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     489     else:
#     490         # dtype check to exclude e.g. range objects, scalars
#     491         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 493 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py:118, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     115 if verify_integrity:
#     116     # figure out the index, if necessary
#     117     if index is None:
# --> 118         index = _extract_index(arrays)
#     119     else:
#     120         index = ensure_index(index)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py:633, in _extract_index(data)
#     631 index = None
#     632 if len(data) == 0:
# --> 633     index = Index([])
#     634 else:
#     635     raw_lengths = []
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:573, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     569     subarr = _maybe_cast_data_without_dtype(
#     570         subarr, cast_numeric_deprecated=False
#     571     )
#     572     dtype = subarr.dtype
# --> 573 return Index(subarr, dtype=dtype, copy=copy, name=name, **kwargs)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:517, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     509     data = data._values
#     511 if dtype is not None:
#     512     # we need to avoid having numpy coerce
#     513     # things that look like ints/floats to ints unless
#     514     # they are actually ints, e.g. '0' and 0.0
#     515     # should not be coerced
#     516     # GH 11836
# --> 517     data = sanitize_array(data, None, dtype=dtype, copy=copy)
#     519     dtype = data.dtype
#     521 if data.dtype.kind in ["i", "u", "f"]:
#     522     # maybe coerce to a sub-class
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/construction.py:534, in sanitize_array(data, index, dtype, copy, raise_cast_failure, allow_2d)
#     531     dtype = dtype.numpy_dtype
#     533 # extract ndarray or ExtensionArray, ensure we have no PandasArray
# --> 534 data = extract_array(data, extract_numpy=True, extract_range=True)
#     536 if isinstance(data, np.ndarray) and data.ndim == 0:
#     537     if dtype is None:
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/construction.py:444, in extract_array(obj, extract_numpy, extract_range)
#     399 def extract_array(
#     400     obj: T, extract_numpy: bool = False, extract_range: bool = False
#     401 ) -> T | ArrayLike:
#     402     """
#     403     Extract the ndarray or ExtensionArray from a Series or Index.
#     404
#    (...)
#     442     array([1, 2, 3])
#     443     """
# --> 444     if isinstance(obj, (ABCIndex, ABCSeries)):
#     445         if isinstance(obj, ABCRangeIndex):
#     446             if extract_range:
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/dtypes/generic.py:47, in create_pandas_abc_type.<locals>._instancecheck(cls, inst)
#      45 @classmethod  # type: ignore[misc]
#      46 def _instancecheck(cls, inst) -> bool:
# ---> 47     return _check(inst) and not isinstance(inst, type)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/dtypes/generic.py:41, in create_pandas_abc_type.<locals>._check(inst)
#      40 def _check(inst):
# ---> 41     return getattr(inst, attr, "_typ") in comp
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
df
# Out:
#        id counter_balance        condition    rt   congruence    soa  correct
# 4     799               A        Con_Synth   824    congruent  short        1
# 5     799               A          Con_Nat   796    congruent  short        1
# 6     799               A  Inc_Synth_Synth   881  incongruent  short        0
# 7     799               A        Con_Synth  1243    congruent  short        1
# 8     799               A          Con_Nat  1956    congruent  short        1
# ...   ...             ...              ...   ...          ...    ...      ...
# 1359  773               B          Con_Nat   737    congruent  short        1
# 1360  773               B    Inc_Nat_Synth   788  incongruent  short        0
# 1361  773               B        Con_Synth  1047    congruent  short        1
# 1362  773               B        Con_Synth   955    congruent  short        1
# 1363  773               B  Inc_Synth_Synth   728  incongruent  short        0
#
# [2760 rows x 7 columns]
