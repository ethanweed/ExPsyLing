# %%
days = []
temp = ""
while temp != "done":
    temp = input("Enter a day name. If you are done, write \"done\".")
    if temp != "done":
        days.append(temp)


meals = []
for day in days:
    meals.append(input("What would you like to make on " + day + "? "))
# Out:
# Enter a day name. If you are done, write "done".Monday
# Enter a day name. If you are done, write "done".Wednesday
# Enter a day name. If you are done, write "done".Sunday
# Enter a day name. If you are done, write "done".done
# What would you like to make on Monday? Tacos
# What would you like to make on Wednesday? Pizza
# What would you like to make on Sunday? Soup

# %%
days
# Out:
# ['Monday', 'Wednesday', 'Sunday']

# %%
meals
# Out:
# ['Tacos', 'Pizza', 'Soup']

# %%
import pandas as pd

df = pd.DataFrame(
    {'days': days,
     'meals': meals
    })

# %%
df
# Out:
#         days  meals
# 0     Monday  Tacos
# 1  Wednesday  Pizza
# 2     Sunday   Soup

# %%
shopping = []
for meal in df['meals']:
    shopping.append(input("What do you need to buy to make " + meal + " ? "))
# Out:
# What do you need to buy to make Tacos ? lettuce, taco shells
# What do you need to buy to make Pizza ? cheese, tomato sauce
# What do you need to buy to make Soup ? onions

# %%
shopping
# Out:
# ['lettuce, taco shells', 'cheese, tomato sauce', 'onions']

# %%
df['shopping'] = shopping
df
# Out:
#         days  meals              shopping
# 0     Monday  Tacos  lettuce, taco shells
# 1  Wednesday  Pizza  cheese, tomato sauce
# 2     Sunday   Soup                onions

# %%
a = list(df['days'])

# %%
list(df.iloc[2])
# Out:
# ['Sunday', 'Soup', 'onions']

# %%
rawdata = pd.read_html("https://en.wikipedia.org/wiki/List_of_best-selling_albums")

# %%
list(rawdata[1].columns)
# Out:
# ['Artist',
#  'Album',
#  'Released',
#  'Genre',
#  'Total certified copies(from available markets)*',
#  'Claimed sales*',
#  'Ref(s)']

# %%
list(rawdata[2].columns)
# Out:
# ['Artist',
#  'Album',
#  'Released',
#  'Genre',
#  'Total certified copies(from available markets)*',
#  'Claimed sales*',
#  'Ref(s)']

# %%
data = pd.concat([rawdata[1], rawdata[2], rawdata[3]])

# %%
data.shape
# Out:
# (81, 7)

# %%
data.head()
# Out:
#                               Artist                            Album  \
# 0                    Michael Jackson                         Thriller
# 1                              AC/DC                    Back in Black
# 2  Whitney Houston / various artists                    The Bodyguard
# 3                          Meat Loaf                  Bat Out of Hell
# 4                             Eagles  Their Greatest Hits (1971–1975)
#
#    Released                                   Genre  \
# 0      1982             Pop, post-disco, funk, rock
# 1      1980                               Hard rock
# 2      1992              R&B, soul, pop, soundtrack
# 3      1977  Hard rock, glam rock, progressive rock
# 4      1976      Country rock, soft rock, folk rock
#
#      Total certified copies(from available markets)*  Claimed sales*  Ref(s)
# 0  48.9 US: 34 million[9] JPN: 100,000[10] UK: 4....              70  [4][5]
# 1  29.6 US: 25 million[9] UK: 600,000[11] GER: 1 ...              50    [32]
# 2  32.4 US: 18 million[9] JPN: 3 million[33] UK: ...              45    [37]
# 3  21.7 US: 14 million[9] UK: 3.3 million[11] GER...              45    [39]
# 4  41.2 US: 38 million[9] UK: 600,000[11] CAN: 2 ...              44    [40]

# %%
data_sorted = data.sort_values(by=['Released'], ascending = False)
data_sorted
# Out:
#                Artist                                  Album  Released  \
# 26              Adele                                     25      2015
# 8               Adele                                     21      2011
# 4         Norah Jones                      Come Away with Me      2002
# 3              Eminem                        The Eminem Show      2002
# 2         Linkin Park                          Hybrid Theory      2000
# ..                ...                                    ...       ...
# 12  Simon & Garfunkel             Bridge over Troubled Water      1970
# 13        The Beatles                             Abbey Road      1969
# 46            The Who                                  Tommy      1969
# 6         The Beatles  Sgt. Pepper's Lonely Hearts Club Band      1967
# 36      Elvis Presley                 Elvis' Christmas Album      1957
#
#                                      Genre  \
# 26                          Soul, pop, R&B
# 8                                Pop, soul
# 4                                     Jazz
# 3                                  Hip hop
# 2   Nu metal, rap metal, alternative metal
# ..                                     ...
# 12                               Folk rock
# 13                                    Rock
# 46                   Hard rock, rock opera
# 6                                     Rock
# 36   Christmas, pop, gospel, rock and roll
#
#       Total certified copies(from available markets)*  Claimed sales*  \
# 26                                                NaN              22
# 8   26.4 US: 14 million[9] JPN: 100,000[73] UK: 6 ...              31
# 4                                                 NaN              27
# 3                                                 NaN              27
# 2                                                 NaN              27
# ..                                                ...             ...
# 12                                                NaN              25
# 13  14.4 US: 12 million[9] GER: 500,000[12] FRA: 1...              31
# 46                                                NaN              20
# 6   18.2 US: 11 million[9] UK: 5.1 million[11] GER...              32
# 36                                                NaN            2520
#
#              Ref(s)
# 26            [147]
# 8              [86]
# 4             [123]
# 3        [121][122]
# 2             [120]
# ..              ...
# 12            [131]
# 13             [97]
# 46            [171]
# 6              [71]
# 36  [159][160][161]
#
# [81 rows x 7 columns]

# %%
data.rename(columns={'Total certified copies(from available markets)*' : 'Copies'})
# Out:
#                                Artist  \
# 0                     Michael Jackson
# 1                               AC/DC
# 2   Whitney Houston / various artists
# 3                           Meat Loaf
# 4                              Eagles
# ..                                ...
# 43                      Tracy Chapman
# 44                    Various artists
# 45                    Whitney Houston
# 46                            The Who
# 47                     Andrea Bocelli
#
#                                                 Album  Released  \
# 0                                            Thriller      1982
# 1                                       Back in Black      1980
# 2                                       The Bodyguard      1992
# 3                                     Bat Out of Hell      1977
# 4                     Their Greatest Hits (1971–1975)      1976
# ..                                                ...       ...
# 43                                      Tracy Chapman      1988
# 44  Flashdance: Original Soundtrack from the Motio...      1983
# 45                                            Whitney      1987
# 46                                              Tommy      1969
# 47                                            Romanza      1997
#
#                                      Genre  \
# 0              Pop, post-disco, funk, rock
# 1                                Hard rock
# 2               R&B, soul, pop, soundtrack
# 3   Hard rock, glam rock, progressive rock
# 4       Country rock, soft rock, folk rock
# ..                                     ...
# 43                               Folk rock
# 44                       Electro, synthpop
# 45                                Pop, R&B
# 46                   Hard rock, rock opera
# 47                       Operatic pop, pop
#
#                                                Copies  Claimed sales*  Ref(s)
# 0   48.9 US: 34 million[9] JPN: 100,000[10] UK: 4....              70  [4][5]
# 1   29.6 US: 25 million[9] UK: 600,000[11] GER: 1 ...              50    [32]
# 2   32.4 US: 18 million[9] JPN: 3 million[33] UK: ...              45    [37]
# 3   21.7 US: 14 million[9] UK: 3.3 million[11] GER...              45    [39]
# 4   41.2 US: 38 million[9] UK: 600,000[11] CAN: 2 ...              44    [40]
# ..                                                ...             ...     ...
# 43                                                NaN              20   [168]
# 44                                                NaN              20   [169]
# 45                                                NaN              20   [170]
# 46                                                NaN              20   [171]
# 47                                                NaN              20   [172]
#
# [81 rows x 7 columns]

# %%
data_sorted = data.sort_values(by=['Artist'])
data_sorted
# Out:
#                                Artist  \
# 14                               ABBA
# 1                               AC/DC
# 20                        Ace of Base
# 26                              Adele
# 8                               Adele
# ..                                ...
# 0                     Various artists
# 44                    Various artists
# 22                    Whitney Houston
# 45                    Whitney Houston
# 2   Whitney Houston / various artists
#
#                                                 Album  Released  \
# 14                                Gold: Greatest Hits      1992
# 1                                       Back in Black      1980
# 20                              Happy Nation/The Sign      1993
# 26                                                 25      2015
# 8                                                  21      2011
# ..                                                ...       ...
# 0   Grease: The Original Soundtrack from the Motio...      1978
# 44  Flashdance: Original Soundtrack from the Motio...      1983
# 22                                    Whitney Houston      1985
# 45                                            Whitney      1987
# 2                                       The Bodyguard      1992
#
#                          Genre  \
# 14                  Pop, disco
# 1                    Hard rock
# 20                         Pop
# 26              Soul, pop, R&B
# 8                    Pop, soul
# ..                         ...
# 0                Rock and roll
# 44           Electro, synthpop
# 22                    Pop, R&B
# 45                    Pop, R&B
# 2   R&B, soul, pop, soundtrack
#
#       Total certified copies(from available markets)*  Claimed sales* Ref(s)
# 14  23.0 US: 6 million[9] JPN: 600,000[98] UK: 5.4...              30  [101]
# 1   29.6 US: 25 million[9] UK: 600,000[11] GER: 1 ...              50   [32]
# 20                                                NaN              23  [139]
# 26                                                NaN              22  [147]
# 8   26.4 US: 14 million[9] JPN: 100,000[73] UK: 6 ...              31   [86]
# ..                                                ...             ...    ...
# 0   14.4 US: 8 million[9] UK: 2.4 million[11] GER:...              38   [55]
# 44                                                NaN              20  [169]
# 22                                                NaN              22  [141]
# 45                                                NaN              20  [170]
# 2   32.4 US: 18 million[9] JPN: 3 million[33] UK: ...              45   [37]
#
# [81 rows x 7 columns]

# %%
years = list(data['Released'])

# %%
decades = []
for year in years:
    if year < 1960:
        decades.append('Fifties')
    elif year <= 1970 & year < 1980:
        decades.append('Sixties')
    else: decades.append('other')

# %%
decades
# Out:
# ['other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'Sixties',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'Fifties',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other',
#  'other']

# %%
pop = []
for i in list(data['Genre']):
    if 'Pop' in i:
        pop.append(1)
    elif 'pop' in i:
            pop.append(1)
    else:
        pop.append(0)
data['Pop'] = pop

# %%
data
# Out:
#                                Artist  \
# 0                     Michael Jackson
# 1                               AC/DC
# 2   Whitney Houston / various artists
# 3                           Meat Loaf
# 4                              Eagles
# ..                                ...
# 43                      Tracy Chapman
# 44                    Various artists
# 45                    Whitney Houston
# 46                            The Who
# 47                     Andrea Bocelli
#
#                                                 Album  Released  \
# 0                                            Thriller      1982
# 1                                       Back in Black      1980
# 2                                       The Bodyguard      1992
# 3                                     Bat Out of Hell      1977
# 4                     Their Greatest Hits (1971–1975)      1976
# ..                                                ...       ...
# 43                                      Tracy Chapman      1988
# 44  Flashdance: Original Soundtrack from the Motio...      1983
# 45                                            Whitney      1987
# 46                                              Tommy      1969
# 47                                            Romanza      1997
#
#                                      Genre  \
# 0              Pop, post-disco, funk, rock
# 1                                Hard rock
# 2               R&B, soul, pop, soundtrack
# 3   Hard rock, glam rock, progressive rock
# 4       Country rock, soft rock, folk rock
# ..                                     ...
# 43                               Folk rock
# 44                       Electro, synthpop
# 45                                Pop, R&B
# 46                   Hard rock, rock opera
# 47                       Operatic pop, pop
#
#       Total certified copies(from available markets)*  Claimed sales*  Ref(s)  \
# 0   48.9 US: 34 million[9] JPN: 100,000[10] UK: 4....              70  [4][5]
# 1   29.6 US: 25 million[9] UK: 600,000[11] GER: 1 ...              50    [32]
# 2   32.4 US: 18 million[9] JPN: 3 million[33] UK: ...              45    [37]
# 3   21.7 US: 14 million[9] UK: 3.3 million[11] GER...              45    [39]
# 4   41.2 US: 38 million[9] UK: 600,000[11] CAN: 2 ...              44    [40]
# ..                                                ...             ...     ...
# 43                                                NaN              20   [168]
# 44                                                NaN              20   [169]
# 45                                                NaN              20   [170]
# 46                                                NaN              20   [171]
# 47                                                NaN              20   [172]
#
#     Pop
# 0     1
# 1     0
# 2     1
# 3     0
# 4     0
# ..  ...
# 43    0
# 44    1
# 45    1
# 46    0
# 47    1
#
# [81 rows x 8 columns]

# %%
data_pop_or_not = data.sort_values(by = ['Pop'], ascending=False)

# %%
data_pop_or_not
# Out:
#                       Artist                                         Album  \
# 0            Michael Jackson                                      Thriller
# 22                Elton John                     Goodbye Yellow Brick Road
# 6             Britney Spears                         ...Baby One More Time
# 8                Carole King                                      Tapestry
# 9               Phil Collins                            No Jacket Required
# ..                       ...                                           ...
# 13               The Beatles                                    Abbey Road
# 12               The Beatles                                             1
# 11                 Metallica                                     Metallica
# 6                The Beatles         Sgt. Pepper's Lonely Hearts Club Band
# 7   Bob Marley & The Wailers  Legend: The Best of Bob Marley & The Wailers
#
#     Released                        Genre  \
# 0       1982  Pop, post-disco, funk, rock
# 22      1973    rock, pop rock, glam rock
# 6       1999                          Pop
# 8       1971                          Pop
# 9       1985                     Pop rock
# ..       ...                          ...
# 13      1969                         Rock
# 12      2000                         Rock
# 11      1991                  Heavy metal
# 6       1967                         Rock
# 7       1984                       Reggae
#
#       Total certified copies(from available markets)*  Claimed sales*  \
# 0   48.9 US: 34 million[9] JPN: 100,000[10] UK: 4....              70
# 22  8.5 US: 8 million[9] UK: 300,000[11] AUS: 210,...              30
# 6                                                 NaN              25
# 8                                                 NaN              25
# 9                                                 NaN              25
# ..                                                ...             ...
# 13  14.4 US: 12 million[9] GER: 500,000[12] FRA: 1...              31
# 12  23.5 US: 12 million[9] JPN: 2 million[10] UK: ...              31
# 11  25.2 US: 16.83 million[9] UK: 900,000[11] GER:...              31
# 6   18.2 US: 11 million[9] UK: 5.1 million[11] GER...              32
# 7                                                 NaN              25
#
#         Ref(s)  Pop
# 0       [4][5]    1
# 22  [116][117]    1
# 6        [125]    1
# 8        [127]    1
# 9        [128]    1
# ..         ...  ...
# 13        [97]    0
# 12        [96]    0
# 11        [93]    0
# 6         [71]    0
# 7        [126]    0
#
# [81 rows x 8 columns]

# %%
born = 1973
list(data.loc[(data['Released'] >= born) & (data['Released'] < born+10)]['Album'])
# Out:
# ['Thriller',
#  'Back in Black',
#  'Bat Out of Hell',
#  'Their Greatest Hits (1971–1975)',
#  'The Dark Side of the Moon',
#  'Hotel California',
#  'Saturday Night Fever',
#  'Rumours',
#  'Grease: The Original Soundtrack from the Motion Picture',
#  'The Wall',
#  'Goodbye Yellow Brick Road',
#  'Greatest Hits',
#  'Greatest Hits',
#  'Off the Wall',
#  'Boston',
#  'Wish You Were Here',
#  'Breakfast in America']
