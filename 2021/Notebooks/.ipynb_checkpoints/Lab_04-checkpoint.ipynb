# %%
import pandas as pd


days = []
temp = ""
while temp != "done":
    temp = input("Enter a day name. If you are done, write \"done\".")
    if temp != "done":
        days.append(temp)


meals = []
for day in days:
    meals.append(input("What would you like to make on " + day + "? "))
    
df = pd.DataFrame(
    {'days': days,
     'meals': meals
    })
# Out:
# Enter a day name. If you are done, write "done".Monday
# Enter a day name. If you are done, write "done".Tuesday
# Enter a day name. If you are done, write "done".Friday
# Enter a day name. If you are done, write "done".done
# What would you like to make on Monday? Soup
# What would you like to make on Tuesday? Salad
# What would you like to make on Friday? Pizza

# %%
df
# Out:
#       days  meals
# 0   Monday   Soup
# 1  Tuesday  Salad
# 2   Friday  Pizza

# %%
shopping = []
for meal in df['meals']:
    shopping.append(input("What do you to buy to make " + meal + " ? "))

df['shopping'] = shopping
# Out:
# What do you to buy to make Soup ? tomatoes, onions, spices
# What do you to buy to make Salad ? lettuce, cukes, dressing
# What do you to buy to make Pizza ? cheese, sauce, toppings

# %%
df
# Out:
#       days  meals                  shopping
# 0   Monday   Soup  tomatoes, onions, spices
# 1  Tuesday  Salad  lettuce, cukes, dressing
# 2   Friday  Pizza   cheese, sauce, toppings

# %%
df['meals']
# Out:
# 0     Soup
# 1    Salad
# 2    Pizza
# Name: meals, dtype: object

# %%
list(df['meals'])
# Out:
# ['Soup', 'Salad', 'Pizza']

# %%
df.iloc[2]
# Out:
# days                         Friday
# meals                         Pizza
# shopping    cheese, sauce, toppings
# Name: 2, dtype: object

# %%
list(df.loc[2])
# Out:
# ['Friday', 'Pizza', 'cheese, sauce, toppings']

# %%
rawdata = pd.read_html("https://en.wikipedia.org/wiki/List_of_best-selling_albums")

# %%
type(rawdata)
# Out:
# list

# %%
rawdata[1].tail()
# Out:
#                        Artist                      Album  Released  \
# 5                  Pink Floyd  The Dark Side of the Moon      1973
# 6                      Eagles           Hotel California      1976
# 7  Bee Gees / Various artists       Saturday Night Fever      1977
# 8               Fleetwood Mac                    Rumours      1977
# 9                Shania Twain               Come On Over      1997
#
#               Genre    Total certified copies(from available markets)*  \
# 5  Progressive rock  24.4 US: 15 million[9] UK: 4.2 million[11] GER...
# 6         Soft rock  31.5 US: 26 million[9] UK: 1.8 million[11] GER...
# 7             Disco  21.6 US: 16 million[9] UK: 2.1 million[11] GER...
# 8         Soft rock  27.9 US: 20 million[9] UK: 3.3 million[11] GER...
# 9      Country, pop  29.6 US: 20 million[9] JPN: 100,000 [10] UK: 3...
#
#    Claimed sales*    Ref(s)
# 5              44      [42]
# 6              42      [43]
# 7              40  [45][46]
# 8              40  [49][50]
# 9              40      [54]

# %%
data = pd.concat([rawdata[1], rawdata[2], rawdata[3]])
data.head()
# Out:
#                               Artist                            Album  \
# 0                    Michael Jackson                         Thriller
# 1                              AC/DC                    Back in Black
# 2  Whitney Houston / various artists                    The Bodyguard
# 3                          Meat Loaf                  Bat Out of Hell
# 4                             Eagles  Their Greatest Hits (1971–1975)
#
#    Released                                   Genre  \
# 0      1982             Pop, post-disco, funk, rock
# 1      1980                               Hard rock
# 2      1992              R&B, soul, pop, soundtrack
# 3      1977  Hard rock, glam rock, progressive rock
# 4      1976      Country rock, soft rock, folk rock
#
#      Total certified copies(from available markets)*  Claimed sales*  Ref(s)
# 0  48.9 US: 34 million[9] JPN: 100,000[10] UK: 4....              70  [4][5]
# 1  29.6 US: 25 million[9] UK: 600,000[11] GER: 1 ...              50    [32]
# 2  32.4 US: 18 million[9] JPN: 3 million[33] UK: ...              45    [37]
# 3  21.7 US: 14 million[9] UK: 3.3 million[11] GER...              45    [39]
# 4  41.2 US: 38 million[9] UK: 600,000[11] CAN: 2 ...              44    [40]

# %%
data.tail()
# Out:
#              Artist                                              Album  \
# 43    Tracy Chapman                                      Tracy Chapman
# 44  Various artists  Flashdance: Original Soundtrack from the Motio...
# 45  Whitney Houston                                            Whitney
# 46          The Who                                              Tommy
# 47   Andrea Bocelli                                            Romanza
#
#     Released                  Genre  \
# 43      1988              Folk rock
# 44      1983      Electro, synthpop
# 45      1987               Pop, R&B
# 46      1969  Hard rock, rock opera
# 47      1997      Operatic pop, pop
#
#    Total certified copies(from available markets)*  Claimed sales* Ref(s)
# 43                                             NaN              20  [168]
# 44                                             NaN              20  [169]
# 45                                             NaN              20  [170]
# 46                                             NaN              20  [171]
# 47                                             NaN              20  [172]

# %%
genres = list(data['Genre'])
genres
# Out:
# ['Pop, post-disco, funk, rock',
#  'Hard rock',
#  'R&B, soul, pop, soundtrack',
#  'Hard rock, glam rock, progressive rock',
#  'Country rock, soft rock, folk rock',
#  'Progressive rock',
#  'Soft rock',
#  'Disco',
#  'Soft rock',
#  'Country, pop',
#  'Rock and roll',
#  'Hard rock, heavy metal, folk rock',
#  'Pop, rhythm and blues, funk and rock',
#  'Alternative rock',
#  'New jack swing, R&B and pop',
#  'Pop, soft rock',
#  'Rock',
#  'Pop, rock, R&B',
#  'Pop, soul',
#  'Pop, dance',
#  'Pop, soft rock',
#  'Heavy metal',
#  'Rock',
#  'Rock',
#  'Pop, disco',
#  'Heartland rock',
#  'Progressive rock',
#  'Film score',
#  'Roots rock, blues rock, soft rock',
#  'Grunge, alternative rock',
#  'Latin rock',
#  'Hard rock',
#  'rock, pop rock, glam rock',
#  'Hard rock, glam metal',
#  'Pop, R&B',
#  'Nu metal, rap metal, alternative metal',
#  'Hip hop',
#  'Jazz',
#  'Acoustic rock, acoustic blues',
#  'Pop',
#  'Reggae',
#  'Pop',
#  'Pop rock',
#  'Rock',
#  'Pop, dance',
#  'Folk rock',
#  'Rock',
#  'Pop rock, new wave, R&B',
#  'Pop, R&B, funk, soul',
#  'Pop',
#  'Pop',
#  'Pop',
#  'Pop',
#  'Pop',
#  'Pop',
#  'Pop, R&B',
#  'Alternative hip hop',
#  'Britpop, rock',
#  'R&B, pop and hip hop',
#  'Soul, pop, R&B',
#  'Pop, dance',
#  'Hip hop',
#  'Hard rock, glam metal',
#  'Disco, pop, funk and R&B',
#  'Neo Soul, R&B and Hip Hop',
#  'Arena rock, hard rock',
#  'Pop',
#  'Pop',
#  'Hard rock, glam metal',
#  'Christmas, pop, gospel, rock and roll',
#  'Pop punk, punk rock, alternative rock',
#  'Pop, R&B, soul',
#  'Pop, R&B',
#  'Progressive rock, art rock, experimental rock',
#  'Country, pop',
#  'Progressive rock, art rock',
#  'Folk rock',
#  'Electro, synthpop',
#  'Pop, R&B',
#  'Hard rock, rock opera',
#  'Operatic pop, pop']

# %%
genres = [x.split(', ') for x in genres]
genres
# Out:
# [['Pop', 'post-disco', 'funk', 'rock'],
#  ['Hard rock'],
#  ['R&B', 'soul', 'pop', 'soundtrack'],
#  ['Hard rock', 'glam rock', 'progressive rock'],
#  ['Country rock', 'soft rock', 'folk rock'],
#  ['Progressive rock'],
#  ['Soft rock'],
#  ['Disco'],
#  ['Soft rock'],
#  ['Country', 'pop'],
#  ['Rock and roll'],
#  ['Hard rock', 'heavy metal', 'folk rock'],
#  ['Pop', 'rhythm and blues', 'funk and rock'],
#  ['Alternative rock'],
#  ['New jack swing', 'R&B and pop'],
#  ['Pop', 'soft rock'],
#  ['Rock'],
#  ['Pop', 'rock', 'R&B'],
#  ['Pop', 'soul'],
#  ['Pop', 'dance'],
#  ['Pop', 'soft rock'],
#  ['Heavy metal'],
#  ['Rock'],
#  ['Rock'],
#  ['Pop', 'disco'],
#  ['Heartland rock'],
#  ['Progressive rock'],
#  ['Film score'],
#  ['Roots rock', 'blues rock', 'soft rock'],
#  ['Grunge', 'alternative rock'],
#  ['Latin rock'],
#  ['Hard rock'],
#  ['rock', 'pop rock', 'glam rock'],
#  ['Hard rock', 'glam metal'],
#  ['Pop', 'R&B'],
#  ['Nu metal', 'rap metal', 'alternative metal'],
#  ['Hip hop'],
#  ['Jazz'],
#  ['Acoustic rock', 'acoustic blues'],
#  ['Pop'],
#  ['Reggae'],
#  ['Pop'],
#  ['Pop rock'],
#  ['Rock'],
#  ['Pop', 'dance'],
#  ['Folk rock'],
#  ['Rock'],
#  ['Pop rock', 'new wave', 'R&B'],
#  ['Pop', 'R&B', 'funk', 'soul'],
#  ['Pop'],
#  ['Pop'],
#  ['Pop'],
#  ['Pop'],
#  ['Pop'],
#  ['Pop'],
#  ['Pop', 'R&B'],
#  ['Alternative hip hop'],
#  ['Britpop', 'rock'],
#  ['R&B', 'pop and hip hop'],
#  ['Soul', 'pop', 'R&B'],
#  ['Pop', 'dance'],
#  ['Hip hop'],
#  ['Hard rock', 'glam metal'],
#  ['Disco', 'pop', 'funk and R&B'],
#  ['Neo Soul', 'R&B and Hip Hop'],
#  ['Arena rock', 'hard rock'],
#  ['Pop'],
#  ['Pop'],
#  ['Hard rock', 'glam metal'],
#  ['Christmas', 'pop', 'gospel', 'rock and roll'],
#  ['Pop punk', 'punk rock', 'alternative rock'],
#  ['Pop', 'R&B', 'soul'],
#  ['Pop', 'R&B'],
#  ['Progressive rock', 'art rock', 'experimental rock'],
#  ['Country', 'pop'],
#  ['Progressive rock', 'art rock'],
#  ['Folk rock'],
#  ['Electro', 'synthpop'],
#  ['Pop', 'R&B'],
#  ['Hard rock', 'rock opera'],
#  ['Operatic pop', 'pop']]

# %%
all_genres = [x for y in genres for x in y]

# %%
all_genres
# Out:
# ['Pop',
#  'post-disco',
#  'funk',
#  'rock',
#  'Hard rock',
#  'R&B',
#  'soul',
#  'pop',
#  'soundtrack',
#  'Hard rock',
#  'glam rock',
#  'progressive rock',
#  'Country rock',
#  'soft rock',
#  'folk rock',
#  'Progressive rock',
#  'Soft rock',
#  'Disco',
#  'Soft rock',
#  'Country',
#  'pop',
#  'Rock and roll',
#  'Hard rock',
#  'heavy metal',
#  'folk rock',
#  'Pop',
#  'rhythm and blues',
#  'funk and rock',
#  'Alternative rock',
#  'New jack swing',
#  'R&B and pop',
#  'Pop',
#  'soft rock',
#  'Rock',
#  'Pop',
#  'rock',
#  'R&B',
#  'Pop',
#  'soul',
#  'Pop',
#  'dance',
#  'Pop',
#  'soft rock',
#  'Heavy metal',
#  'Rock',
#  'Rock',
#  'Pop',
#  'disco',
#  'Heartland rock',
#  'Progressive rock',
#  'Film score',
#  'Roots rock',
#  'blues rock',
#  'soft rock',
#  'Grunge',
#  'alternative rock',
#  'Latin rock',
#  'Hard rock',
#  'rock',
#  'pop rock',
#  'glam rock',
#  'Hard rock',
#  'glam metal',
#  'Pop',
#  'R&B',
#  'Nu metal',
#  'rap metal',
#  'alternative metal',
#  'Hip hop',
#  'Jazz',
#  'Acoustic rock',
#  'acoustic blues',
#  'Pop',
#  'Reggae',
#  'Pop',
#  'Pop rock',
#  'Rock',
#  'Pop',
#  'dance',
#  'Folk rock',
#  'Rock',
#  'Pop rock',
#  'new wave',
#  'R&B',
#  'Pop',
#  'R&B',
#  'funk',
#  'soul',
#  'Pop',
#  'Pop',
#  'Pop',
#  'Pop',
#  'Pop',
#  'Pop',
#  'Pop',
#  'R&B',
#  'Alternative hip hop',
#  'Britpop',
#  'rock',
#  'R&B',
#  'pop and hip hop',
#  'Soul',
#  'pop',
#  'R&B',
#  'Pop',
#  'dance',
#  'Hip hop',
#  'Hard rock',
#  'glam metal',
#  'Disco',
#  'pop',
#  'funk and R&B',
#  'Neo Soul',
#  'R&B and Hip Hop',
#  'Arena rock',
#  'hard rock',
#  'Pop',
#  'Pop',
#  'Hard rock',
#  'glam metal',
#  'Christmas',
#  'pop',
#  'gospel',
#  'rock and roll',
#  'Pop punk',
#  'punk rock',
#  'alternative rock',
#  'Pop',
#  'R&B',
#  'soul',
#  'Pop',
#  'R&B',
#  'Progressive rock',
#  'art rock',
#  'experimental rock',
#  'Country',
#  'pop',
#  'Progressive rock',
#  'art rock',
#  'Folk rock',
#  'Electro',
#  'synthpop',
#  'Pop',
#  'R&B',
#  'Hard rock',
#  'rock opera',
#  'Operatic pop',
#  'pop']

# %%
g = set(all_genres)

# %%
g
# Out:
# {'Acoustic rock',
#  'Alternative hip hop',
#  'Alternative rock',
#  'Arena rock',
#  'Britpop',
#  'Christmas',
#  'Country',
#  'Country rock',
#  'Disco',
#  'Electro',
#  'Film score',
#  'Folk rock',
#  'Grunge',
#  'Hard rock',
#  'Heartland rock',
#  'Heavy metal',
#  'Hip hop',
#  'Jazz',
#  'Latin rock',
#  'Neo Soul',
#  'New jack swing',
#  'Nu metal',
#  'Operatic pop',
#  'Pop',
#  'Pop punk',
#  'Pop rock',
#  'Progressive rock',
#  'R&B',
#  'R&B and Hip Hop',
#  'R&B and pop',
#  'Reggae',
#  'Rock',
#  'Rock and roll',
#  'Roots rock',
#  'Soft rock',
#  'Soul',
#  'acoustic blues',
#  'alternative metal',
#  'alternative rock',
#  'art rock',
#  'blues rock',
#  'dance',
#  'disco',
#  'experimental rock',
#  'folk rock',
#  'funk',
#  'funk and R&B',
#  'funk and rock',
#  'glam metal',
#  'glam rock',
#  'gospel',
#  'hard rock',
#  'heavy metal',
#  'new wave',
#  'pop',
#  'pop and hip hop',
#  'pop rock',
#  'post-disco',
#  'progressive rock',
#  'punk rock',
#  'rap metal',
#  'rhythm and blues',
#  'rock',
#  'rock and roll',
#  'rock opera',
#  'soft rock',
#  'soul',
#  'soundtrack',
#  'synthpop'}
