# %%
#slicing
#type
#len
#pandas dataframes

# %%
a = [4, 5, 8, 5, 6, 7, 9, 10, 55]

# %%
type(a)
# Out:
# list

# %%
len(a)
# Out:
# 9

# %%
b = "I am a string!"
len(b)
# Out:
# 14

# %%
a[3:100]
# Out:
# [5, 6, 7, 9, 10, 55]

# %%
a = [4, 5, 8, 5, 6, 7, 9, 10, 55]

# %%
a[-2:]
# Out:
# [10, 55]

# %%
len(a)
# Out:
# 9
